# %%
import pymongo
myclient = pymongo.MongoClient(
    "mongodb://finder:finder@irinka.cn:26926/homefinder")
mydb = myclient["homefinder"]
region_array=mydb["sales_records"].aggregate([
    {
        '$group': {
        '_id': "$sub_region",
        'region': {'$first': "$region"},
        'sub_region': {'$first': "$sub_region"},
    },
    },
    {'$project': {
        '_id': 0
    }
    }
])
print(region_array)

regions=[]
for i in region_array:
    
    regions.append(i)
# Out:
# <pymongo.command_cursor.CommandCursor object at 0x00000295AC8D0C70>

# %%
region_dic={}
for i in regions:
    region_name=i['region']
    print(region_name)
    if region_name in region_dic:
        pass
    else:
        region_dic[region_name]=[]
    region_dic[region_name].append(i['sub_region'])

# print(region_dic)
# Out:
# {'region': '东城', 'sub_region': '崇文门'}
# 东城
# {'region': '丰台', 'sub_region': '刘家窑'}
# 丰台
# {'region': '亦庄开发区', 'sub_region': '亦庄'}
# 亦庄开发区
# {'region': '海淀', 'sub_region': '二里庄'}
# 海淀
# {'region': '海淀', 'sub_region': '军博'}
# 海淀
# {'region': '丰台', 'sub_region': '和义'}
# 丰台
# {'region': '丰台', 'sub_region': '北大地'}
# 丰台
# {'region': '朝阳', 'sub_region': '三元桥'}
# 朝阳
# {'region': '朝阳', 'sub_region': 'CBD'}
# 朝阳
# {'region': '朝阳', 'sub_region': '东坝'}
# 朝阳
# {'region': '东城', 'sub_region': '和平里'}
# 东城
# {'region': '朝阳', 'sub_region': '北苑'}
# 朝阳
# {'region': '丰台', 'sub_region': '太平桥'}
# 丰台
# {'region': '海淀', 'sub_region': '新街口'}
# 海淀
# {'region': '朝阳', 'sub_region': '大山子'}
# 朝阳
# {'region': '朝阳', 'sub_region': '石佛营'}
# 朝阳
# {'region': '丰台', 'sub_region': '宋家庄'}
# 丰台
# {'region': '朝阳', 'sub_region': '方庄'}
# 朝阳
# {'region': '海淀', 'sub_region': '北太平庄'}
# 海淀
# {'region': '朝阳', 'sub_region': '牡丹园'}
# 朝阳
# {'region': '东城', 'sub_region': '建国门内'}
# 东城
# {'region': '朝阳', 'sub_region': '双桥'}
# 朝阳
# {'region': '昌平', 'sub_region': '南口'}
# 昌平
# {'region': '朝阳', 'sub_region': '潘家园'}
# 朝阳
# {'region': '朝阳', 'sub_region': '华威桥'}
# 朝阳
# {'region': '通州', 'sub_region': '万达'}
# 通州
# {'region': '海淀', 'sub_region': '六里桥'}
# 海淀
# {'region': '大兴', 'sub_region': '黄村中'}
# 大兴
# {'region': '朝阳', 'sub_region': '西坝河'}
# 朝阳
# {'region': '昌平', 'sub_region': '西关环岛'}
# 昌平
# {'region': '昌平', 'sub_region': '回龙观'}
# 昌平
# {'region': '海淀', 'sub_region': '小西天'}
# 海淀
# {'region': '东城', 'sub_region': '工体'}
# 东城
# {'region': '丰台', 'sub_region': '看丹桥'}
# 丰台
# {'region': '朝阳', 'sub_region': '管庄'}
# 朝阳
# {'region': '东城', 'sub_region': '灯市口'}
# 东城
# {'region': '西城', 'sub_region': '牛街'}
# 西城
# {'region': '朝阳', 'sub_region': '豆各庄'}
# 朝阳
# {'region': '朝阳', 'sub_region': '定福庄'}
# 朝阳
# {'region': '西城', 'sub_region': '西四'}
# 西城
# {'region': '顺义', 'sub_region': '顺义其它'}
# 顺义
# {'region': '东城', 'sub_region': '左安门'}
# 东城
# {'region': '海淀', 'sub_region': '上地'}
# 海淀
# {'region': '海淀', 'sub_region': '四季青'}
# 海淀
# {'region': '大兴', 'sub_region': '义和庄'}
# 大兴
# {'region': '东城', 'sub_region': '东花市'}
# 东城
# {'region': '大兴', 'sub_region': '大兴新机场洋房别墅区'}
# 大兴
# {'region': '石景山', 'sub_region': '八角'}
# 石景山
# {'region': '丰台', 'sub_region': '右安门外'}
# 丰台
# {'region': '东城', 'sub_region': '东直门'}
# 东城
# {'region': '西城', 'sub_region': '德胜门'}
# 西城
# {'region': '海淀', 'sub_region': '知春路'}
# 海淀
# {'region': '朝阳', 'sub_region': '酒仙桥'}
# 朝阳
# {'region': '丰台', 'sub_region': '五里店'}
# 丰台
# {'region': '朝阳', 'sub_region': '农展馆'}
# 朝阳
# {'region': '通州', 'sub_region': '潞苑'}
# 通州
# {'region': '通州', 'sub_region': '果园'}
# 通州
# {'region': '朝阳', 'sub_region': '三里屯'}
# 朝阳
# {'region': '海淀', 'sub_region': '魏公村'}
# 海淀
# {'region': '海淀', 'sub_region': '马连洼'}
# 海淀
# {'region': '东城', 'sub_region': '朝阳门外'}
# 东城
# {'region': '通州', 'sub_region': '乔庄'}
# 通州
# {'region': '丰台', 'sub_region': '卢沟桥'}
# 丰台
# {'region': '昌平', 'sub_region': '鼓楼大街'}
# 昌平
# {'region': '亦庄开发区', 'sub_region': '马驹桥'}
# 亦庄开发区
# {'region': '东城', 'sub_region': '东单'}
# 东城
# {'region': '丰台', 'sub_region': '花乡'}
# 丰台
# {'region': '丰台', 'sub_region': '科技园区'}
# 丰台
# {'region': '昌平', 'sub_region': '东关'}
# 昌平
# {'region': '门头沟', 'sub_region': '大峪'}
# 门头沟
# {'region': '密云', 'sub_region': '密云其它'}
# 密云
# {'region': '海淀', 'sub_region': '中关村'}
# 海淀
# {'region': '大兴', 'sub_region': '瀛海'}
# 大兴
# {'region': '东城', 'sub_region': '金宝街'}
# 东城
# {'region': '东城', 'sub_region': '永定门'}
# 东城
# {'region': '西城', 'sub_region': '官园'}
# 西城
# {'region': '丰台', 'sub_region': '马连道'}
# 丰台
# {'region': '通州', 'sub_region': '临河里'}
# 通州
# {'region': '西城', 'sub_region': '金融街'}
# 西城
# {'region': '通州', 'sub_region': '北关'}
# 通州
# {'region': '东城', 'sub_region': '建国门外'}
# 东城
# {'region': '门头沟', 'sub_region': '冯村'}
# 门头沟
# {'region': '石景山', 'sub_region': '苹果园'}
# 石景山
# {'region': '朝阳', 'sub_region': '芍药居'}
# 朝阳
# {'region': '丰台', 'sub_region': '七里庄'}
# 丰台
# {'region': '东城', 'sub_region': '安定门'}
# 东城
# {'region': '石景山', 'sub_region': '老山'}
# 石景山
# {'region': '朝阳', 'sub_region': '十里堡'}
# 朝阳
# {'region': '西城', 'sub_region': '天宁寺'}
# 西城
# {'region': '海淀', 'sub_region': '学院路'}
# 海淀
# {'region': '海淀', 'sub_region': '苏州桥'}
# 海淀
# {'region': '房山', 'sub_region': '阎村'}
# 房山
# {'region': '亦庄开发区', 'sub_region': '通州其它'}
# 亦庄开发区
# {'region': '顺义', 'sub_region': '后沙峪'}
# 顺义
# {'region': '怀柔', 'sub_region': '怀柔'}
# 怀柔
# {'region': '海淀', 'sub_region': '皂君庙'}
# 海淀
# {'region': '海淀', 'sub_region': '清河'}
# 海淀
# {'region': '顺义', 'sub_region': '顺义城'}
# 顺义
# {'region': '朝阳', 'sub_region': '朝青'}
# 朝阳
# {'region': '朝阳', 'sub_region': '亮马桥'}
# 朝阳
# {'region': '朝阳', 'sub_region': '首都机场'}
# 朝阳
# {'region': '朝阳', 'sub_region': '朝阳其它'}
# 朝阳
# {'region': '海淀', 'sub_region': '万柳'}
# 海淀
# {'region': '朝阳', 'sub_region': '马甸'}
# 朝阳
# {'region': '亦庄开发区', 'sub_region': '大兴其它'}
# 亦庄开发区
# {'region': '西城', 'sub_region': '地安门'}
# 西城
# {'region': '房山', 'sub_region': '燕山'}
# 房山
# {'region': '东城', 'sub_region': '西单'}
# 东城
# {'region': '朝阳', 'sub_region': '劲松'}
# 朝阳
# {'region': '昌平', 'sub_region': '安宁庄'}
# 昌平
# {'region': '朝阳', 'sub_region': '垡头'}
# 朝阳
# {'region': '海淀', 'sub_region': '公主坟'}
# 海淀
# {'region': '大兴', 'sub_region': '黄村火车站'}
# 大兴
# {'region': '西城', 'sub_region': '右安门内'}
# 西城
# {'region': '平谷', 'sub_region': '平谷其它'}
# 平谷
# {'region': '海淀', 'sub_region': '五道口'}
# 海淀
# {'region': '海淀', 'sub_region': '定慧寺'}
# 海淀
# {'region': '东城', 'sub_region': '天坛'}
# 东城
# {'region': '丰台', 'sub_region': '十里河'}
# 丰台
# {'region': '海淀', 'sub_region': '杨庄'}
# 海淀
# {'region': '海淀', 'sub_region': '海淀北部新区'}
# 海淀
# {'region': '海淀', 'sub_region': '玉泉路'}
# 海淀
# {'region': '朝阳', 'sub_region': '亚运村小营'}
# 朝阳
# {'region': '通州', 'sub_region': '梨园'}
# 通州
# {'region': '丰台', 'sub_region': '木樨园'}
# 丰台
# {'region': '朝阳', 'sub_region': '太阳宫'}
# 朝阳
# {'region': '房山', 'sub_region': '房山其它'}
# 房山
# {'region': '朝阳', 'sub_region': '红庙'}
# 朝阳
# {'region': '大兴', 'sub_region': '枣园'}
# 大兴
# {'region': '丰台', 'sub_region': '丰台其它'}
# 丰台
# {'region': '丰台', 'sub_region': '菜户营'}
# 丰台
# {'region': '东城', 'sub_region': '洋桥'}
# 东城
# {'region': '大兴', 'sub_region': '天宫院南'}
# 大兴
# {'region': '门头沟', 'sub_region': '石门营'}
# 门头沟
# {'region': '朝阳', 'sub_region': '惠新西街'}
# 朝阳
# {'region': '西城', 'sub_region': '长椿街'}
# 西城
# {'region': '朝阳', 'sub_region': '甘露园'}
# 朝阳
# {'region': '朝阳', 'sub_region': '亚运村'}
# 朝阳
# {'region': '丰台', 'sub_region': '大红门'}
# 丰台
# {'region': '朝阳', 'sub_region': '十八里店'}
# 朝阳
# {'region': '东城', 'sub_region': '北京南站'}
# 东城
# {'region': '朝阳', 'sub_region': '南沙滩'}
# 朝阳
# {'region': '西城', 'sub_region': '白纸坊'}
# 西城
# {'region': '昌平', 'sub_region': '昌平其它'}
# 昌平
# {'region': '朝阳', 'sub_region': '国展'}
# 朝阳
# {'region': '海淀', 'sub_region': '西直门'}
# 海淀
# {'region': '丰台', 'sub_region': '玉泉营'}
# 丰台
# {'region': '海淀', 'sub_region': '西北旺'}
# 海淀
# {'region': '海淀', 'sub_region': '甘家口'}
# 海淀
# {'region': '朝阳', 'sub_region': '朝阳公园'}
# 朝阳
# {'region': '丰台', 'sub_region': '西红门'}
# 丰台
# {'region': '昌平', 'sub_region': '北七家'}
# 昌平
# {'region': '海淀', 'sub_region': '双榆树'}
# 海淀
# {'region': '房山', 'sub_region': '窦店'}
# 房山
# {'region': '海淀', 'sub_region': '海淀其它'}
# 海淀
# {'region': '大兴', 'sub_region': '南中轴机场商务区'}
# 大兴
# {'region': '昌平', 'sub_region': '沙河'}
# 昌平
# {'region': '丰台', 'sub_region': '马家堡'}
# 丰台
# {'region': '丰台', 'sub_region': '角门'}
# 丰台
# {'region': '朝阳', 'sub_region': '大望路'}
# 朝阳
# {'region': '丰台', 'sub_region': '青塔'}
# 丰台
# {'region': '海淀', 'sub_region': '西山'}
# 海淀
# {'region': '朝阳', 'sub_region': '健翔桥'}
# 朝阳
# {'region': '朝阳', 'sub_region': '燕莎'}
# 朝阳
# {'region': '顺义', 'sub_region': '天竺'}
# 顺义
# {'region': '朝阳', 'sub_region': '望京'}
# 朝阳
# {'region': '顺义', 'sub_region': '马坡'}
# 顺义
# {'region': '大兴', 'sub_region': '天宫院'}
# 大兴
# {'region': '朝阳', 'sub_region': '东大桥'}
# 朝阳
# {'region': '东城', 'sub_region': '安贞'}
# 东城
# {'region': '海淀', 'sub_region': '万寿路'}
# 海淀
# {'region': '亦庄开发区', 'sub_region': '亦庄开发区其它'}
# 亦庄开发区
# {'region': '海淀', 'sub_region': '圆明园'}
# 海淀
# {'region': '朝阳', 'sub_region': '常营'}
# 朝阳
# {'region': '朝阳', 'sub_region': '中央别墅区'}
# 朝阳
# {'region': '石景山', 'sub_region': '石景山其它'}
# 石景山
# {'region': '昌平', 'sub_region': '霍营'}
# 昌平
# {'region': '石景山', 'sub_region': '鲁谷'}
# 石景山
# {'region': '西城', 'sub_region': '阜成门'}
# 西城
# {'region': '石景山', 'sub_region': '门头沟其它'}
# 石景山
# {'region': '丰台', 'sub_region': '成寿寺'}
# 丰台
# {'region': '门头沟', 'sub_region': '滨河西区'}
# 门头沟
# {'region': '东城', 'sub_region': '西罗园'}
# 东城
# {'region': '通州', 'sub_region': '武夷花园'}
# 通州
# {'region': '海淀', 'sub_region': '紫竹桥'}
# 海淀
# {'region': '昌平', 'sub_region': '奥林匹克公园'}
# 昌平
# {'region': '西城', 'sub_region': '木樨地'}
# 西城
# {'region': '房山', 'sub_region': '韩村河'}
# 房山
# {'region': '昌平', 'sub_region': '小汤山'}
# 昌平
# {'region': '西城', 'sub_region': '六铺炕'}
# 西城
# {'region': '海淀', 'sub_region': '世纪城'}
# 海淀
# {'region': '丰台', 'sub_region': '赵公口'}
# 丰台
# {'region': '东城', 'sub_region': '前门'}
# 东城
# {'region': '丰台', 'sub_region': '丽泽'}
# 丰台
# {'region': '昌平', 'sub_region': '西三旗'}
# 昌平
# {'region': '大兴', 'sub_region': '大兴新机场'}
# 大兴
# {'region': '通州', 'sub_region': '九棵树(家乐福)'}
# 通州
# {'region': '东城', 'sub_region': '交道口'}
# 东城
# {'region': '昌平', 'sub_region': '立水桥'}
# 昌平
# {'region': '朝阳', 'sub_region': '通州北苑'}
# 朝阳
# {'region': '昌平', 'sub_region': '南邵'}
# 昌平
# {'region': '西城', 'sub_region': '月坛'}
# 西城
# {'region': '石景山', 'sub_region': '城子'}
# 石景山
# {'region': '朝阳', 'sub_region': '百子湾'}
# 朝阳
# {'region': '朝阳', 'sub_region': '团结湖'}
# 朝阳
# {'region': '朝阳', 'sub_region': '北工大'}
# 朝阳
# {'region': '朝阳', 'sub_region': '双井'}
# 朝阳
# {'region': '东城', 'sub_region': '广渠门'}
# 东城
# {'region': '海淀', 'sub_region': '田村'}
# 海淀
# {'region': '房山', 'sub_region': '琉璃河'}
# 房山
# {'region': '东城', 'sub_region': '朝阳门内'}
# 东城
# {'region': '昌平', 'sub_region': '天通苑'}
# 昌平
# {'region': '朝阳', 'sub_region': '四惠'}
# 朝阳
# {'region': '西城', 'sub_region': '车公庄'}
# 西城
# {'region': '石景山', 'sub_region': '古城'}
# 石景山
# {'region': '房山', 'sub_region': '良乡'}
# 房山
# {'region': '大兴', 'sub_region': '观音寺'}
# 大兴
# {'region': '海淀', 'sub_region': '西二旗'}
# 海淀
# {'region': '丰台', 'sub_region': '广安门'}
# 丰台
# {'region': '朝阳', 'sub_region': '欢乐谷'}
# 朝阳
# {'region': '房山', 'sub_region': '城关'}
# 房山
# {'region': '海淀', 'sub_region': '白石桥'}
# 海淀
# {'region': '东城', 'sub_region': '陶然亭'}
# 东城
# {'region': '丰台', 'sub_region': '新宫'}
# 丰台
# {'region': '顺义', 'sub_region': '李桥'}
# 顺义
# {'region': '房山', 'sub_region': '长阳'}
# 房山
# {'region': '丰台', 'sub_region': '五棵松'}
# 丰台
# {'region': '朝阳', 'sub_region': '高碑店'}
# 朝阳
# {'region': '海淀', 'sub_region': '厂洼'}
# 海淀
# {'region': '东城', 'sub_region': '蒲黄榆'}
# 东城
# {'region': '丰台', 'sub_region': '草桥'}
# 丰台
# {'region': '延庆', 'sub_region': '延庆其它'}
# 延庆
# {'region': '丰台', 'sub_region': '岳各庄'}
# 丰台
# {'region': '朝阳', 'sub_region': '甜水园'}
# 朝阳
# {'region': '丰台', 'sub_region': '旧宫'}
# 丰台
# {'region': '大兴', 'sub_region': '高米店'}
# 大兴
# {'region': '西城', 'sub_region': '宣武门'}
# 西城
# {'region': '东城', 'sub_region': '东四'}
# 东城
# {'region': '海淀', 'sub_region': '颐和园'}
# 海淀
# {'region': '通州', 'sub_region': '玉桥'}
# 通州

# %%
import json
json.dump(region_dic,open("./region_subreigon.json",'w'))
